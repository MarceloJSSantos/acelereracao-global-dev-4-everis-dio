# %% [markdown]
# **Criando pipelines de dados eficientes - Parte 1 (Spark Streaming e PySpark)**
#
# **PRÁTICA**

# %%
from pyspark.sql import SparkSession
# cria ou busca por uma Spark Session
spark_session = SparkSession.builder.enableHiveSupport().getOrCreate()
# 2 formas de acessar o Spark Context a partir da Spark Session
spark_context = spark_session._sc
spark_context = spark_session.sparkContext
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# retona informações sobre o Spark Context
spark_context
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: </div>
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=6130611863355689#setting/sparkui/0131-221435-zip814/driver-8823081648903292928">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.0.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>

# %%
from pyspark.streaming import StreamingContext

ssc = StreamingContext(sc, 1)
lines = ssc.socketTextStream('localhost', 9999)
counts = lines.flatMap(lambda line: line.split(" ")).map(lambda word: (word, 1)).reduceByKey(lambda a, b: a+b)
counts.pprint()
ssc.start()
ssc.awaitTermination()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">-------------------------------------------
# Time: 2021-01-31 23:48:56
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-31 23:48:57
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-31 23:48:58
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-31 23:48:59
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-31 23:49:00
# -------------------------------------------
#
# ...
